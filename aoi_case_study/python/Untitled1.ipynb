# %% [markdown]
# # Plot bathymetry for the model domain

# %%
# allow plots to be interactive in the notebook
# %matplotlib notebook

import numpy as np
import pandas as pd
import xarray as xr
from datetime import datetime
import cartopy.crs as ccrs
import os 
import sys
from glob import glob
import matplotlib.pyplot as plt
import matplotlib.colors as colors

# %%
outpath_plots = '/cluster/work/users/rheinlender/plots/'

fl = '/cluster/work/users/rheinlender/nextsim_data_dir/ETOPO_Arctic_2arcmin.nc' 

# Open nc file
ds = xr.open_dataset(fl)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (lat: 1501, lon: 10800)
# Coordinates:
#   * lon      (lon) float64 -180.0 -180.0 -179.9 -179.9 ... 179.9 179.9 180.0
#   * lat      (lat) float64 40.0 40.03 40.07 40.1 40.13 ... 89.9 89.93 89.97 90.0
# Data variables:
#     z        (lat, lon) float64 ...
# Attributes:
#     CDI:          Climate Data Interface version 1.7.2 (http://mpimet.mpg.de/...
#     Conventions:  COARDS/CF-1.0
#     history:      Tue Oct 25 13:10:55 2016: cdo sellonlatbox,-180,180,40,90 -...
#     title:        ETOPO1_Ice_g_gmt4.grd
#     GMT_version:  4.4.0
#     node_offset:  0
#     CDO:          Climate Data Operators version 1.7.2 (http://mpimet.mpg.de/...

# %%
 levels=[-6000,-5000,-3000, -2000, -1500, -1000,-500, -400, -300, -250, -200, -150, -100, -75, -65, -50, -35, -25, -15, -10, -5, 0]

# %%
crs=ccrs.NorthPolarStereo()

fig = plt.figure(figsize=(6,6))
#ax = fig.add_subplot(111, projection=crs)
ax = fig.add_subplot(111)

im=ax.imshow(ds.z)

#cf = ax.contourf(ds.lon,ds.lat, ds.z, transform=ccrs.PlateCarree())
#ax.coastlines('50m')
fig.colorbar(im)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="600">
